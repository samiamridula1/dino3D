# %%
gm_over=False
score=0
speed=10
g=9.8
jump_power=9
velo=0
obstacle_dis=30
dino_y=0
delta_time=0.015
obsta_z_axis=obstacle_dis
def jump():
  global velo
  if dino_y<=0:
    velo=jump_power
def update():
  global velo
  global score
  global gm_over
  global obstacle_dis
  global dino_y
  global obstacle_z
  velo-=g*delta_time
  dino_y+=velo*delta_time
  if dino_y<=0:
    dino_y=0
    velo=0
  obstacle_z-=speed*delta_time
  if collision(dino,obstacle):
    gm_over=True
    print("Game Over")
def game_over():
  return gm_over
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2468/1705130210.py in <cell line: 0>()
#      17 def game_over():
#      18   return
# ---> 19 velo-=g*delta_time
#      20 dino_y+=velo*delta_time
#      21 if dino_y<=0:
#
# NameError: name 'delta_time' is not defined
